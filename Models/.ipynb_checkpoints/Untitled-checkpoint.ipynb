# %%
from torchvision import datasets
import torch
from torchvision import transforms
import os
import pandas as pd
import load_without_faces
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def save_recon(data):
    inv_normalize = transforms.Normalize(mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],std=[1/0.229, 1/0.224, 1/0.225])

    #fig,ax = plt.subplots(1)
    #ax.set_aspect('equal')

    # obtain one batch of training images
    #dataiter = iter(valloader)
    #images, labels = dataiter.next()
    data = data.detach().cpu()
    data= data.squeeze(0)

    fig = plt.figure(figsize=(30, 20))
    # display 20 images
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        im = inv_normalize(data[idx])
        ax.imshow(im.permute(1, 2, 0))

    for idx in range(10,20):
        ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
        im = inv_normalize(data[idx])
        ax.imshow(im.permute(1, 2, 0))
        
    for idx in range(20,30):
        ax = fig.add_subplot(3, 10, idx+1, xticks=[], yticks=[])
        im = inv_normalize(data[idx])
        ax.imshow(im.permute(1, 2, 0))

   # plt.savefig(f'{curr_dir}/Results/recons/{model_type}_{train_cond}_{epoch}_reconstruction.png', bbox_inches='tight', pad_inches = 0, dpi=200)

# %%
transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                             std=[0.229, 0.224, 0.225])])

inv_normalize = transforms.Normalize(mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],std=[1/0.229, 1/0.224, 1/0.225])

# %%
image_dir = "/lab_data/behrmannlab/image_sets/imagenet_objects/val"
exclude_im = f"/lab_data/behrmannlab/image_sets/imagenet_face_files.csv"
exclude_folder = f"/lab_data/behrmannlab/image_sets/imagenet_animal_classes.csv"
all_classes = os.listdir(image_dir)

# %%
no_faces = load_without_faces.load_stim(image_dir,exclude_im, exclude_folder, transform=transform)

# %%
valloader = torch.utils.data.DataLoader(no_faces, batch_size=30, shuffle = True)
inputs, classes = next(iter(valloader))   
save_recon(inputs)
# Out:
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03874599/ILSVRC2012_val_00004826.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04125021/ILSVRC2012_val_00042845.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n07720875/ILSVRC2012_val_00002766.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n02788148/ILSVRC2012_val_00037594.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03372029/ILSVRC2012_val_00007509.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04243546/ILSVRC2012_val_00032348.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03461385/ILSVRC2012_val_00043522.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n02692877/ILSVRC2012_val_00036036.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n07745940/ILSVRC2012_val_00042197.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n07836838/ILSVRC2012_val_00001483.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n12057211/ILSVRC2012_val_00049906.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04285008/ILSVRC2012_val_00045210.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03544143/ILSVRC2012_val_00001943.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04133789/ILSVRC2012_val_00028994.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03538406/ILSVRC2012_val_00003194.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04606251/ILSVRC2012_val_00006894.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04336792/ILSVRC2012_val_00042085.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n02999410/ILSVRC2012_val_00021778.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n07718472/ILSVRC2012_val_00037754.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n02834397/ILSVRC2012_val_00003192.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03670208/ILSVRC2012_val_00037457.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03393912/ILSVRC2012_val_00013595.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n02916936/ILSVRC2012_val_00047632.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n12620546/ILSVRC2012_val_00043304.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03110669/ILSVRC2012_val_00047890.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n02730930/ILSVRC2012_val_00028783.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04599235/ILSVRC2012_val_00001417.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04428191/ILSVRC2012_val_00002879.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n04467665/ILSVRC2012_val_00030748.JPEG
# /lab_data/behrmannlab/image_sets/imagenet_objects/val/n03444034/ILSVRC2012_val_00029399.JPEG
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9de150079343> in <module>
#       1 valloader = torch.utils.data.DataLoader(no_faces, batch_size=30, shuffle = True)
#       2 inputs, classes = next(iter(valloader))
# ----> 3 save_recon(inputs)
#
# <ipython-input-9-043892a7f4e4> in save_recon(data)
#      13     fig = plt.figure(figsize=(30, 20))
#      14     # display 20 images
# ---> 15     for idx in np.arange(10):
#      16         ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
#      17         im = inv_normalize(data[idx])
#
# NameError: name 'np' is not defined

# %%
fig = plt.figure()

for im, labe in range(len(no_faces)):
    sample, label = no_faces[i]

    #print(i, sample['image'].shape, sample['landmarks'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_landmarks(**sample)

    if i == 3:
        plt.show()
        break

# %%
main_dir = image_dir

all_classes = os.listdir(main_dir)


#load files to exclude
exclude_ims = pd.read_csv(exclude_ims)
exclude_ims = set(exclude_ims['url'])

#exclude certain folders

imgs =[]
class_label =[]
ii = 0
for im_folder in all_classes:
    curr_ims = [os.path.join(im_folder,file) for file in os.listdir(os.path.join(main_dir, im_folder))]
    curr_ims = set(curr_ims)
    final_ims = list(curr_ims - exclude_ims)

    imgs += final_ims
    class_label += [ii] *len(final_ims)
    ii += 1

final_imgs = imgs
samples = class_label

# %%
samples[700]
# Out:
# 14

# %%
img_loc = os.path.join(main_dir, final_imgs[700])

# %%
img_loc
# Out:
# '/lab_data/behrmannlab/image_sets/imagenet_objects/validation/n03450230/ILSVRC2012_val_00018276.JPEG'

# %%
image = Image.open(img_loc).convert("RGB")

# %%
image.imshow()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-faca996ac906> in <module>
# ----> 1 image.imshow()
#
# AttributeError: 'Image' object has no attribute 'imshow'

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
image = Image.open(img_loc).convert("RGB")
imshow(np.asarray(image))
